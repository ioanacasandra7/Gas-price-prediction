# %%
import requests
from config import API_KEY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# ## Get Data from eia API

# %%
eastCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R10_DPG.W"
midwest = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R20_DPG.W"
gulfCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R30_DPG.W"
rockyMountain = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R40_DPG.W"
westCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R50_DPG.W"

# %%
eastCoast_df = pd.DataFrame(requests.get(eastCoast).json()['series'][0]['data'])
midwest_df = pd.DataFrame(requests.get(midwest).json()['series'][0]['data'])
gulfCoast_df = pd.DataFrame(requests.get(gulfCoast).json()['series'][0]['data'])
rockyMountain_df = pd.DataFrame(requests.get(rockyMountain).json()['series'][0]['data'])
westCoast_df = pd.DataFrame(requests.get(westCoast).json()['series'][0]['data'])

# %%
eastCoast_df.rename(columns = {0:"week", 1:"price_eastCoast"}, inplace = True)
midwest_df.rename(columns = {0:"week", 1:"price_midwest"}, inplace = True)
gulfCoast_df.rename(columns = {0:"week", 1:"price_gulfCoast"}, inplace = True)
rockyMountain_df.rename(columns = {0:"week", 1:"price_rockyMountain"}, inplace = True)
westCoast_df.rename(columns = {0:"week", 1:"price_westCoast"}, inplace = True)

# %%
eastCoast_df['week'] = pd.to_datetime(eastCoast_df['week'])
midwest_df['week'] = pd.to_datetime(midwest_df['week'])
gulfCoast_df['week'] = pd.to_datetime(gulfCoast_df['week'])
rockyMountain_df['week'] = pd.to_datetime(rockyMountain_df['week'])
westCoast_df['week'] = pd.to_datetime(westCoast_df['week'])

# %%
prices_df = eastCoast_df.merge(midwest_df , on = "week", suffixes=('', ''))\
            .merge(gulfCoast_df , on = "week", suffixes=('', ''))\
            .merge(rockyMountain_df , on = "week", suffixes=('', ''))\
            .merge(westCoast_df , on = "week", suffixes=('', ''))

# %%
regions = ["eastCoast", "midwest", "gulfCoast", "rockyMountain", "westCoast"]
for region in regions:
    prices_df['change_' + region] = prices_df['price_' + region].diff()

# %%
prices_df
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-16            2.152          2.021            1.858
# 1    2020-11-09            2.127          2.025            1.823
# 2    2020-11-02            2.149          2.026            1.862
# 3    2020-10-26            2.173          2.069            1.908
# 4    2020-10-19            2.196          2.057            1.905
# ...         ...              ...            ...              ...
# 1437 1993-05-03            1.062          1.073            1.084
# 1438 1993-04-26            1.059          1.078            1.081
# 1439 1993-04-19            1.054          1.067            1.081
# 1440 1993-04-12            1.047          1.077            1.071
# 1441 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.300            2.864               NaN             NaN
# 1                   2.304            2.863            -0.025           0.004
# 2                   2.320            2.869             0.022           0.001
# 3                   2.340            2.882             0.024           0.043
# 4                   2.359            2.887             0.023          -0.012
# ...                   ...              ...               ...             ...
# 1437                1.161            1.161            -0.007          -0.018
# 1438                1.169            1.157            -0.003           0.005
# 1439                1.120            1.155            -0.005          -0.011
# 1440                1.118            1.154            -0.007           0.010
# 1441                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast
# 0                  NaN                   NaN               NaN
# 1               -0.035                 0.004            -0.001
# 2                0.039                 0.016             0.006
# 3                0.046                 0.020             0.013
# 4               -0.003                 0.019             0.005
# ...                ...                   ...               ...
# 1437            -0.004                 0.018            -0.010
# 1438            -0.003                 0.008            -0.004
# 1439             0.000                -0.049            -0.002
# 1440            -0.010                -0.002            -0.001
# 1441            -0.007                -0.025            -0.002
#
# [1442 rows x 11 columns]

# %%
prices_df.dropna(inplace =True)

# %%
prices_df.plot(x = 'week', y=["change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"])
# Out:
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# ### Add in WTI spot price

# %%
WTI = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.RWTC.W"

# %%
WTI_df = pd.DataFrame(requests.get(WTI).json()['series'][0]['data'])

# %%
WTI_df.rename(columns = {0:"week", 1:"WTI_spotPrice"}, inplace = True)

# %%
WTI_df['week'] = pd.to_datetime(WTI_df['week']) + datetime.timedelta(days = 3)

# %%
WTI_df ['change_WTI'] = WTI_df['WTI_spotPrice'].diff()

# %%
#normalize WTI_change so that it is about the size of gas Price changes (100 is somewhat arbitrary)
WTI_df ['change_WTI_normalized'] = WTI_df ['change_WTI'] / 100

# %%
combined_df = prices_df.merge(WTI_df, on = 'week', suffixes=("",""))

# %% [markdown]
# ### Add in Import/ Export

# %%
petroleum_export = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.WTTEXUS2.W"
petroleum_import = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.WTTIMUS2.W"

# %%
export_df = pd.DataFrame(requests.get(petroleum_export).json()['series'][0]['data'])
import_df = pd.DataFrame(requests.get(petroleum_import).json()['series'][0]['data'])

# %%
export_df.rename(columns = {0:"week", 1:"export_barrels"}, inplace = True)
import_df.rename(columns = {0:"week", 1:"import_barrels"}, inplace = True)

# %%
export_df['week'] = pd.to_datetime(eastCoast_df['week'])
import_df['week'] = pd.to_datetime(midwest_df['week'])

# %%
#niormalize number of import/export barrels (1000000 is somehwat arbitrary)
export_df['export_barrels_normalized'] = export_df['export_barrels']/100000
import_df['import_barrels_normalized'] = import_df['import_barrels']/100000

# %%
combined_df = combined_df.merge(export_df, on = 'week', suffixes=("",""))\
          .merge(import_df, on = 'week', suffixes=("",""))

# %%
combined_df
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-09            2.127          2.025            1.823
# 1    2020-11-02            2.149          2.026            1.862
# 2    2020-10-26            2.173          2.069            1.908
# 3    2020-10-19            2.196          2.057            1.905
# 4    2020-10-12            2.209          2.089            1.914
# ...         ...              ...            ...              ...
# 1436 1993-05-03            1.062          1.073            1.084
# 1437 1993-04-26            1.059          1.078            1.081
# 1438 1993-04-19            1.054          1.067            1.081
# 1439 1993-04-12            1.047          1.077            1.071
# 1440 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.304            2.863            -0.025           0.004
# 1                   2.320            2.869             0.022           0.001
# 2                   2.340            2.882             0.024           0.043
# 3                   2.359            2.887             0.023          -0.012
# 4                   2.367            2.895             0.013           0.032
# ...                   ...              ...               ...             ...
# 1436                1.161            1.161            -0.007          -0.018
# 1437                1.169            1.157            -0.003           0.005
# 1438                1.120            1.155            -0.005          -0.011
# 1439                1.118            1.154            -0.007           0.010
# 1440                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 0               -0.035                 0.004            -0.001          37.71
# 1                0.039                 0.016             0.006          37.32
# 2                0.046                 0.020             0.013          40.43
# 3               -0.003                 0.019             0.005          40.33
# 4                0.009                 0.008             0.008          40.19
# ...                ...                   ...               ...            ...
# 1436            -0.004                 0.018            -0.010          20.30
# 1437            -0.003                 0.008            -0.004          19.95
# 1438             0.000                -0.049            -0.002          20.28
# 1439            -0.010                -0.002            -0.001          20.37
# 1440            -0.007                -0.025            -0.002          20.44
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 0          -2.95                -0.0295            7566
# 1          -0.39                -0.0039            7568
# 2           3.11                 0.0311            8082
# 3          -0.10                -0.0010            8028
# 4          -0.14                -0.0014            7525
# ...          ...                    ...             ...
# 1436       -0.17                -0.0017             981
# 1437       -0.35                -0.0035             986
# 1438        0.33                 0.0033             986
# 1439        0.09                 0.0009             986
# 1440        0.07                 0.0007             986
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 0                       0.07566            7386                    0.07386
# 1                       0.07568            6767                    0.06767
# 2                       0.08082            7966                    0.07966
# 3                       0.08028            6968                    0.06968
# 4                       0.07525            7321                    0.07321
# ...                         ...             ...                        ...
# 1436                    0.00981            9418                    0.09418
# 1437                    0.00986            8715                    0.08715
# 1438                    0.00986            7976                    0.07976
# 1439                    0.00986            8956                    0.08956
# 1440                    0.00986            7501                    0.07501
#
# [1441 rows x 18 columns]

# %% [markdown]
# ## Processs the data

# %%
#train test split
train_size = int(0.8 * len(prices_df))
combined_df_train = combined_df.iloc[0:train_size]
combined_df_test = combined_df.iloc[train_size:]

# %%
combined_df_train
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-09            2.127          2.025            1.823
# 1    2020-11-02            2.149          2.026            1.862
# 2    2020-10-26            2.173          2.069            1.908
# 3    2020-10-19            2.196          2.057            1.905
# 4    2020-10-12            2.209          2.089            1.914
# ...         ...              ...            ...              ...
# 1147 1998-11-16            1.031          1.000            0.991
# 1148 1998-11-09            1.038          1.026            0.998
# 1149 1998-11-02            1.040          1.025            1.002
# 1150 1998-10-26            1.041          1.032            1.007
# 1151 1998-10-19            1.044          1.038            1.014
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.304            2.863            -0.025           0.004
# 1                   2.320            2.869             0.022           0.001
# 2                   2.340            2.882             0.024           0.043
# 3                   2.359            2.887             0.023          -0.012
# 4                   2.367            2.895             0.013           0.032
# ...                   ...              ...               ...             ...
# 1147                1.141            1.169             0.009           0.009
# 1148                1.120            1.169             0.007           0.026
# 1149                1.128            1.172             0.002          -0.001
# 1150                1.136            1.175             0.001           0.007
# 1151                1.138            1.174             0.003           0.006
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 0               -0.035                 0.004            -0.001          37.71
# 1                0.039                 0.016             0.006          37.32
# 2                0.046                 0.020             0.013          40.43
# 3               -0.003                 0.019             0.005          40.33
# 4                0.009                 0.008             0.008          40.19
# ...                ...                   ...               ...            ...
# 1147             0.010                 0.016            -0.010          13.63
# 1148             0.007                -0.021             0.000          14.13
# 1149             0.004                 0.008             0.003          14.34
# 1150             0.005                 0.008             0.003          13.81
# 1151             0.007                 0.002            -0.001          14.21
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 0          -2.95                -0.0295            7566
# 1          -0.39                -0.0039            7568
# 2           3.11                 0.0311            8082
# 3          -0.10                -0.0010            8028
# 4          -0.14                -0.0014            7525
# ...          ...                    ...             ...
# 1147        1.23                 0.0123             985
# 1148        0.50                 0.0050             985
# 1149        0.21                 0.0021            1010
# 1150       -0.53                -0.0053            1010
# 1151        0.40                 0.0040            1010
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 0                       0.07566            7386                    0.07386
# 1                       0.07568            6767                    0.06767
# 2                       0.08082            7966                    0.07966
# 3                       0.08028            6968                    0.06968
# 4                       0.07525            7321                    0.07321
# ...                         ...             ...                        ...
# 1147                    0.00985            9818                    0.09818
# 1148                    0.00985           10455                    0.10455
# 1149                    0.01010           10363                    0.10363
# 1150                    0.01010            9982                    0.09982
# 1151                    0.01010            9944                    0.09944
#
# [1152 rows x 18 columns]

# %%
combined_df_test
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 1152 1998-10-12            1.046          1.045            1.015
# 1153 1998-10-05            1.034          1.050            1.003
# 1154 1998-09-28            1.029          1.041            0.995
# 1155 1998-09-21            1.023          1.047            0.989
# 1156 1998-09-14            1.024          1.020            0.989
# ...         ...              ...            ...              ...
# 1436 1993-05-03            1.062          1.073            1.084
# 1437 1993-04-26            1.059          1.078            1.081
# 1438 1993-04-19            1.054          1.067            1.081
# 1439 1993-04-12            1.047          1.077            1.071
# 1440 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 1152                1.148            1.178             0.002           0.007
# 1153                1.130            1.182            -0.012           0.005
# 1154                1.135            1.187            -0.005          -0.009
# 1155                1.149            1.189            -0.006           0.006
# 1156                1.152            1.171             0.001          -0.027
# ...                   ...              ...               ...             ...
# 1436                1.161            1.161            -0.007          -0.018
# 1437                1.169            1.157            -0.003           0.005
# 1438                1.120            1.155            -0.005          -0.011
# 1439                1.118            1.154            -0.007           0.010
# 1440                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 1152             0.001                 0.010             0.004          15.02
# 1153            -0.012                -0.018             0.004          15.83
# 1154            -0.008                 0.005             0.005          15.78
# 1155            -0.006                 0.014             0.002          14.88
# 1156             0.000                 0.003            -0.018          14.45
# ...                ...                   ...               ...            ...
# 1436            -0.004                 0.018            -0.010          20.30
# 1437            -0.003                 0.008            -0.004          19.95
# 1438             0.000                -0.049            -0.002          20.28
# 1439            -0.010                -0.002            -0.001          20.37
# 1440            -0.007                -0.025            -0.002          20.44
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 1152        0.81                 0.0081            1010
# 1153        0.81                 0.0081            1010
# 1154       -0.05                -0.0005             982
# 1155       -0.90                -0.0090             982
# 1156       -0.43                -0.0043             982
# ...          ...                    ...             ...
# 1436       -0.17                -0.0017             981
# 1437       -0.35                -0.0035             986
# 1438        0.33                 0.0033             986
# 1439        0.09                 0.0009             986
# 1440        0.07                 0.0007             986
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 1152                    0.01010           10704                    0.10704
# 1153                    0.01010           10169                    0.10169
# 1154                    0.00982           10900                    0.10900
# 1155                    0.00982            9405                    0.09405
# 1156                    0.00982           10455                    0.10455
# ...                         ...             ...                        ...
# 1436                    0.00981            9418                    0.09418
# 1437                    0.00986            8715                    0.08715
# 1438                    0.00986            7976                    0.07976
# 1439                    0.00986            8956                    0.08956
# 1440                    0.00986            7501                    0.07501
#
# [289 rows x 18 columns]

# %%
#function for making windows
def make_windows(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 4
X_train, y_train = make_windows(combined_df_train[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], combined_df_train[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], time_steps)
X_test, y_test = make_windows(combined_df_test[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], combined_df_test[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], time_steps)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1148, 4, 8) (1148, 8) (285, 4, 8) (285, 8)

# %% [markdown]
# ## Build Model

# %%
from tensorflow import keras
import tensorflow as tf

# %%
model = keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    keras.layers.GRU(units = 8, input_shape=(X_train.shape[1],X_train.shape[2]), return_sequences=False),
    keras.layers.Dense(units=8)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 8)                 432
# _________________________________________________________________
# dense (Dense)                (None, 8)                 72
# =================================================================
# Total params: 504
# Trainable params: 504
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.output_shape
# Out:
# (None, 8)

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=keras.optimizers.Adam(0.001),
    metrics=["mean_absolute_error"]
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=40,
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/40
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0407
# Epoch 2/40
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0322
# Epoch 3/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0020 - mean_absolute_error: 0.0304
# Epoch 4/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0289A: 0s - loss: 0.0021 - mean_absolute_error: 0.03
# Epoch 5/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0278
# Epoch 6/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0270
# Epoch 7/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0263
# Epoch 8/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0258
# Epoch 9/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0254
# Epoch 10/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0250
# Epoch 11/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0246
# Epoch 12/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0244
# Epoch 13/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0241
# Epoch 14/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0239
# Epoch 15/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0237
# Epoch 16/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0236
# Epoch 17/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0234
# Epoch 18/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0233
# Epoch 19/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0232
# Epoch 20/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0230
# Epoch 21/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0229
# Epoch 22/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0228
# Epoch 23/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0227
# Epoch 24/40
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0227
# Epoch 25/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0226
# Epoch 26/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0225
# Epoch 27/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0224
# Epoch 28/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0223
# Epoch 29/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0222
# Epoch 30/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0222
# Epoch 31/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0221
# Epoch 32/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0220
# Epoch 33/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0219
# Epoch 34/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0219
# Epoch 35/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0218
# Epoch 36/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0217
# Epoch 37/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0217
# Epoch 38/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0216
# Epoch 39/40
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0215
# Epoch 40/40
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0215

# %%
history

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.01668058,  0.1167279 ,  0.00094728, ...,  0.0040984 ,
#          0.01030176,  0.00717229],
#        [ 0.01243696,  0.12032868,  0.00077664, ...,  0.00840789,
#          0.00896895,  0.00730548],
#        [ 0.01317339,  0.11914961,  0.00175335, ...,  0.00031271,
#         -0.00125993, -0.00508357],
#        ...,
#        [ 0.01883712,  0.11285266,  0.00212411, ...,  0.00244531,
#          0.00912541,  0.00336077],
#        [ 0.01766754,  0.11257796,  0.00125568, ..., -0.01696857,
#         -0.01673776, -0.02533606],
#        [ 0.020366  ,  0.11064942,  0.0014917 , ..., -0.01572073,
#         -0.01167947, -0.01767276]], dtype=float32)

# %%
y_test
# Out:
# array([[ 0.00982,  0.10455, -0.0043 , ...,  0.     ,  0.003  , -0.018  ],
#        [ 0.00982,  0.10054, -0.0047 , ...,  0.     , -0.016  ,  0.008  ],
#        [ 0.00966,  0.11234, -0.0033 , ...,  0.01   ,  0.015  ,  0.005  ],
#        ...,
#        [ 0.00986,  0.07976,  0.0033 , ...,  0.     , -0.049  , -0.002  ],
#        [ 0.00986,  0.08956,  0.0009 , ..., -0.01   , -0.002  , -0.001  ],
#        [ 0.00986,  0.07501,  0.0007 , ..., -0.007  , -0.025  , -0.002  ]])

# %%
model.evaluate(X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 2.9303e-04 - mean_absolute_error: 0.0128
# [0.0002930286282207817, 0.012795903719961643]

# %%
model.metrics_names
# Out:
# ['loss', 'mean_absolute_error']

# %%
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['mean_absolute_error'])

# %%
y_err = np.abs(y_pred - y_test)

# %%
fig, ax = plt.subplots()
ax.plot(y_err)
# Out:
# [<matplotlib.lines.Line2D at 0x14dfd5e0dc8>,
#  <matplotlib.lines.Line2D at 0x14d82f9a1c8>,
#  <matplotlib.lines.Line2D at 0x14d82fd5508>,
#  <matplotlib.lines.Line2D at 0x14d82fd5608>,
#  <matplotlib.lines.Line2D at 0x14d82fd57c8>,
#  <matplotlib.lines.Line2D at 0x14d82fd5988>,
#  <matplotlib.lines.Line2D at 0x14d82fd5ac8>,
#  <matplotlib.lines.Line2D at 0x14d82fd5c48>]

# %% [markdown]
# ## Save Model

# %%
#model.save("all_channel_GRU.h5")

# %%
#!tensorflowjs_converter --input_format keras "all_channel_LSTM.h5" ./all_channel_GRU_js

# %% [markdown]
# model:
# timesteps: 4
# feature 1: export => /100000 => NNmodel=> predicted value/100000
# feature 2: import => /100000 => NNmodel => predicted value/100000
# feature 3: WTI => difference => /100 => NNmodel => predicted difference/100
# feature 4: eastCoast => difference => NNmodel => predicted difference => +last price => predicted price
# feature 5: midwest => difference => NNmodel => predicted difference => +last price => predicted price
# feature 6: gulfCoast => difference => NNmodel => predicted difference => +last price => predicted price
# feature 7: rockyMountain => difference => NNmodel => predicted difference => +last price => predicted price
# feature 8: westCoast => difference => NNmodel => predicted difference => +last price => predicted price
