# %%
import requests
from config import API_KEY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# ## Get Data from eia API

# %%
eastCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R10_DPG.W"
midwest = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R20_DPG.W"
gulfCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R30_DPG.W"
rockyMountain = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R40_DPG.W"
westCoast = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.EMM_EPM0_PTE_R50_DPG.W"

# %%
eastCoast_df = pd.DataFrame(requests.get(eastCoast).json()['series'][0]['data'])
midwest_df = pd.DataFrame(requests.get(midwest).json()['series'][0]['data'])
gulfCoast_df = pd.DataFrame(requests.get(gulfCoast).json()['series'][0]['data'])
rockyMountain_df = pd.DataFrame(requests.get(rockyMountain).json()['series'][0]['data'])
westCoast_df = pd.DataFrame(requests.get(westCoast).json()['series'][0]['data'])

# %%
eastCoast_df.rename(columns = {0:"week", 1:"price_eastCoast"}, inplace = True)
midwest_df.rename(columns = {0:"week", 1:"price_midwest"}, inplace = True)
gulfCoast_df.rename(columns = {0:"week", 1:"price_gulfCoast"}, inplace = True)
rockyMountain_df.rename(columns = {0:"week", 1:"price_rockyMountain"}, inplace = True)
westCoast_df.rename(columns = {0:"week", 1:"price_westCoast"}, inplace = True)

# %%
eastCoast_df['week'] = pd.to_datetime(eastCoast_df['week'])
midwest_df['week'] = pd.to_datetime(midwest_df['week'])
gulfCoast_df['week'] = pd.to_datetime(gulfCoast_df['week'])
rockyMountain_df['week'] = pd.to_datetime(rockyMountain_df['week'])
westCoast_df['week'] = pd.to_datetime(westCoast_df['week'])

# %%
prices_df = eastCoast_df.merge(midwest_df , on = "week", suffixes=('', ''))\
            .merge(gulfCoast_df , on = "week", suffixes=('', ''))\
            .merge(rockyMountain_df , on = "week", suffixes=('', ''))\
            .merge(westCoast_df , on = "week", suffixes=('', ''))

# %%
regions = ["eastCoast", "midwest", "gulfCoast", "rockyMountain", "westCoast"]
for region in regions:
    prices_df['change_' + region] = prices_df['price_' + region].diff()

# %%
prices_df
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-09            2.127          2.025            1.823
# 1    2020-11-02            2.149          2.026            1.862
# 2    2020-10-26            2.173          2.069            1.908
# 3    2020-10-19            2.196          2.057            1.905
# 4    2020-10-12            2.209          2.089            1.914
# ...         ...              ...            ...              ...
# 1436 1993-05-03            1.062          1.073            1.084
# 1437 1993-04-26            1.059          1.078            1.081
# 1438 1993-04-19            1.054          1.067            1.081
# 1439 1993-04-12            1.047          1.077            1.071
# 1440 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.304            2.863               NaN             NaN
# 1                   2.320            2.869             0.022           0.001
# 2                   2.340            2.882             0.024           0.043
# 3                   2.359            2.887             0.023          -0.012
# 4                   2.367            2.895             0.013           0.032
# ...                   ...              ...               ...             ...
# 1436                1.161            1.161            -0.007          -0.018
# 1437                1.169            1.157            -0.003           0.005
# 1438                1.120            1.155            -0.005          -0.011
# 1439                1.118            1.154            -0.007           0.010
# 1440                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast
# 0                  NaN                   NaN               NaN
# 1                0.039                 0.016             0.006
# 2                0.046                 0.020             0.013
# 3               -0.003                 0.019             0.005
# 4                0.009                 0.008             0.008
# ...                ...                   ...               ...
# 1436            -0.004                 0.018            -0.010
# 1437            -0.003                 0.008            -0.004
# 1438             0.000                -0.049            -0.002
# 1439            -0.010                -0.002            -0.001
# 1440            -0.007                -0.025            -0.002
#
# [1441 rows x 11 columns]

# %%
prices_df.dropna(inplace =True)

# %%
prices_df.plot(x = 'week', y=["change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"])
# Out:
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# ### Add in WTI spot price

# %%
WTI = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.RWTC.W"

# %%
WTI_df = pd.DataFrame(requests.get(WTI).json()['series'][0]['data'])

# %%
WTI_df.rename(columns = {0:"week", 1:"WTI_spotPrice"}, inplace = True)

# %%
WTI_df['week'] = pd.to_datetime(WTI_df['week']) + datetime.timedelta(days = 3)

# %%
WTI_df ['change_WTI'] = WTI_df['WTI_spotPrice'].diff()

# %%
#normalize WTI_change so that it is about the size of gas Price changes (100 is somewhat arbitrary)
WTI_df ['change_WTI_normalized'] = WTI_df ['change_WTI'] / 100

# %%
combined_df = prices_df.merge(WTI_df, on = 'week', suffixes=("",""))

# %% [markdown]
# ### Add in Import/ Export

# %%
petroleum_export = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.WTTEXUS2.W"
petroleum_import = f"http://api.eia.gov/series/?api_key={API_KEY}&series_id=PET.WTTIMUS2.W"

# %%
export_df = pd.DataFrame(requests.get(petroleum_export).json()['series'][0]['data'])
import_df = pd.DataFrame(requests.get(petroleum_import).json()['series'][0]['data'])

# %%
export_df.rename(columns = {0:"week", 1:"export_barrels"}, inplace = True)
import_df.rename(columns = {0:"week", 1:"import_barrels"}, inplace = True)

# %%
export_df['week'] = pd.to_datetime(eastCoast_df['week'])
import_df['week'] = pd.to_datetime(midwest_df['week'])

# %%
#niormalize number of import/export barrels (1000000 is somehwat arbitrary)
export_df['export_barrels_normalized'] = export_df['export_barrels']/100000
import_df['import_barrels_normalized'] = import_df['import_barrels']/100000

# %%
combined_df = combined_df.merge(export_df, on = 'week', suffixes=("",""))\
          .merge(import_df, on = 'week', suffixes=("",""))

# %%
combined_df
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-02            2.149          2.026            1.862
# 1    2020-10-26            2.173          2.069            1.908
# 2    2020-10-19            2.196          2.057            1.905
# 3    2020-10-12            2.209          2.089            1.914
# 4    2020-10-05            2.208          2.106            1.901
# ...         ...              ...            ...              ...
# 1435 1993-05-03            1.062          1.073            1.084
# 1436 1993-04-26            1.059          1.078            1.081
# 1437 1993-04-19            1.054          1.067            1.081
# 1438 1993-04-12            1.047          1.077            1.071
# 1439 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.320            2.869             0.022           0.001
# 1                   2.340            2.882             0.024           0.043
# 2                   2.359            2.887             0.023          -0.012
# 3                   2.367            2.895             0.013           0.032
# 4                   2.376            2.903            -0.001           0.017
# ...                   ...              ...               ...             ...
# 1435                1.161            1.161            -0.007          -0.018
# 1436                1.169            1.157            -0.003           0.005
# 1437                1.120            1.155            -0.005          -0.011
# 1438                1.118            1.154            -0.007           0.010
# 1439                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 0                0.039                 0.016             0.006          37.32
# 1                0.046                 0.020             0.013          40.43
# 2               -0.003                 0.019             0.005          40.33
# 3                0.009                 0.008             0.008          40.19
# 4               -0.013                 0.009             0.008          38.99
# ...                ...                   ...               ...            ...
# 1435            -0.004                 0.018            -0.010          20.30
# 1436            -0.003                 0.008            -0.004          19.95
# 1437             0.000                -0.049            -0.002          20.28
# 1438            -0.010                -0.002            -0.001          20.37
# 1439            -0.007                -0.025            -0.002          20.44
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 0          -0.39                -0.0039            7568
# 1           3.11                 0.0311            8082
# 2          -0.10                -0.0010            8028
# 3          -0.14                -0.0014            7525
# 4          -1.20                -0.0120            7899
# ...          ...                    ...             ...
# 1435       -0.17                -0.0017             981
# 1436       -0.35                -0.0035             986
# 1437        0.33                 0.0033             986
# 1438        0.09                 0.0009             986
# 1439        0.07                 0.0007             986
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 0                       0.07568            6767                    0.06767
# 1                       0.08082            7966                    0.07966
# 2                       0.08028            6968                    0.06968
# 3                       0.07525            7321                    0.07321
# 4                       0.07899            7889                    0.07889
# ...                         ...             ...                        ...
# 1435                    0.00981            9418                    0.09418
# 1436                    0.00986            8715                    0.08715
# 1437                    0.00986            7976                    0.07976
# 1438                    0.00986            8956                    0.08956
# 1439                    0.00986            7501                    0.07501
#
# [1440 rows x 18 columns]

# %% [markdown]
# ## Processs the data

# %%
#train test split
train_size = int(0.8 * len(prices_df))
combined_df_train = combined_df.iloc[0:train_size]
combined_df_test = combined_df.iloc[train_size:]

# %%
combined_df_train
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 0    2020-11-02            2.149          2.026            1.862
# 1    2020-10-26            2.173          2.069            1.908
# 2    2020-10-19            2.196          2.057            1.905
# 3    2020-10-12            2.209          2.089            1.914
# 4    2020-10-05            2.208          2.106            1.901
# ...         ...              ...            ...              ...
# 1147 1998-11-09            1.038          1.026            0.998
# 1148 1998-11-02            1.040          1.025            1.002
# 1149 1998-10-26            1.041          1.032            1.007
# 1150 1998-10-19            1.044          1.038            1.014
# 1151 1998-10-12            1.046          1.045            1.015
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 0                   2.320            2.869             0.022           0.001
# 1                   2.340            2.882             0.024           0.043
# 2                   2.359            2.887             0.023          -0.012
# 3                   2.367            2.895             0.013           0.032
# 4                   2.376            2.903            -0.001           0.017
# ...                   ...              ...               ...             ...
# 1147                1.120            1.169             0.007           0.026
# 1148                1.128            1.172             0.002          -0.001
# 1149                1.136            1.175             0.001           0.007
# 1150                1.138            1.174             0.003           0.006
# 1151                1.148            1.178             0.002           0.007
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 0                0.039                 0.016             0.006          37.32
# 1                0.046                 0.020             0.013          40.43
# 2               -0.003                 0.019             0.005          40.33
# 3                0.009                 0.008             0.008          40.19
# 4               -0.013                 0.009             0.008          38.99
# ...                ...                   ...               ...            ...
# 1147             0.007                -0.021             0.000          14.13
# 1148             0.004                 0.008             0.003          14.34
# 1149             0.005                 0.008             0.003          13.81
# 1150             0.007                 0.002            -0.001          14.21
# 1151             0.001                 0.010             0.004          15.02
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 0          -0.39                -0.0039            7568
# 1           3.11                 0.0311            8082
# 2          -0.10                -0.0010            8028
# 3          -0.14                -0.0014            7525
# 4          -1.20                -0.0120            7899
# ...          ...                    ...             ...
# 1147        0.50                 0.0050             985
# 1148        0.21                 0.0021            1010
# 1149       -0.53                -0.0053            1010
# 1150        0.40                 0.0040            1010
# 1151        0.81                 0.0081            1010
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 0                       0.07568            6767                    0.06767
# 1                       0.08082            7966                    0.07966
# 2                       0.08028            6968                    0.06968
# 3                       0.07525            7321                    0.07321
# 4                       0.07899            7889                    0.07889
# ...                         ...             ...                        ...
# 1147                    0.00985           10455                    0.10455
# 1148                    0.01010           10363                    0.10363
# 1149                    0.01010            9982                    0.09982
# 1150                    0.01010            9944                    0.09944
# 1151                    0.01010           10704                    0.10704
#
# [1152 rows x 18 columns]

# %%
combined_df_test
# Out:
#            week  price_eastCoast  price_midwest  price_gulfCoast  \
# 1152 1998-10-05            1.034          1.050            1.003
# 1153 1998-09-28            1.029          1.041            0.995
# 1154 1998-09-21            1.023          1.047            0.989
# 1155 1998-09-14            1.024          1.020            0.989
# 1156 1998-09-07            1.028          1.027            0.989
# ...         ...              ...            ...              ...
# 1435 1993-05-03            1.062          1.073            1.084
# 1436 1993-04-26            1.059          1.078            1.081
# 1437 1993-04-19            1.054          1.067            1.081
# 1438 1993-04-12            1.047          1.077            1.071
# 1439 1993-04-05            1.040          1.061            1.064
#
#       price_rockyMountain  price_westCoast  change_eastCoast  change_midwest  \
# 1152                1.130            1.182            -0.012           0.005
# 1153                1.135            1.187            -0.005          -0.009
# 1154                1.149            1.189            -0.006           0.006
# 1155                1.152            1.171             0.001          -0.027
# 1156                1.136            1.179             0.004           0.007
# ...                   ...              ...               ...             ...
# 1435                1.161            1.161            -0.007          -0.018
# 1436                1.169            1.157            -0.003           0.005
# 1437                1.120            1.155            -0.005          -0.011
# 1438                1.118            1.154            -0.007           0.010
# 1439                1.093            1.152            -0.007          -0.016
#
#       change_gulfCoast  change_rockyMountain  change_westCoast  WTI_spotPrice  \
# 1152            -0.012                -0.018             0.004          15.83
# 1153            -0.008                 0.005             0.005          15.78
# 1154            -0.006                 0.014             0.002          14.88
# 1155             0.000                 0.003            -0.018          14.45
# 1156             0.000                -0.016             0.008          13.98
# ...                ...                   ...               ...            ...
# 1435            -0.004                 0.018            -0.010          20.30
# 1436            -0.003                 0.008            -0.004          19.95
# 1437             0.000                -0.049            -0.002          20.28
# 1438            -0.010                -0.002            -0.001          20.37
# 1439            -0.007                -0.025            -0.002          20.44
#
#       change_WTI  change_WTI_normalized  export_barrels  \
# 1152        0.81                 0.0081            1010
# 1153       -0.05                -0.0005             982
# 1154       -0.90                -0.0090             982
# 1155       -0.43                -0.0043             982
# 1156       -0.47                -0.0047             982
# ...          ...                    ...             ...
# 1435       -0.17                -0.0017             981
# 1436       -0.35                -0.0035             986
# 1437        0.33                 0.0033             986
# 1438        0.09                 0.0009             986
# 1439        0.07                 0.0007             986
#
#       export_barrels_normalized  import_barrels  import_barrels_normalized
# 1152                    0.01010           10169                    0.10169
# 1153                    0.00982           10900                    0.10900
# 1154                    0.00982            9405                    0.09405
# 1155                    0.00982           10455                    0.10455
# 1156                    0.00982           10054                    0.10054
# ...                         ...             ...                        ...
# 1435                    0.00981            9418                    0.09418
# 1436                    0.00986            8715                    0.08715
# 1437                    0.00986            7976                    0.07976
# 1438                    0.00986            8956                    0.08956
# 1439                    0.00986            7501                    0.07501
#
# [288 rows x 18 columns]

# %%
#function for making windows
def make_windows(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 4
X_train, y_train = make_windows(combined_df_train[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], combined_df_train[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], time_steps)
X_test, y_test = make_windows(combined_df_test[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], combined_df_test[['export_barrels_normalized', 'import_barrels_normalized', 'change_WTI_normalized', "change_eastCoast", "change_midwest", "change_gulfCoast", "change_rockyMountain", "change_westCoast"]], time_steps)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1148, 4, 8) (1148, 8) (284, 4, 8) (284, 8)

# %% [markdown]
# ## Build Model

# %%
from tensorflow import keras
import tensorflow as tf

# %%
model = keras.models.Sequential([
    keras.Input(shape=(X_train.shape[1],X_train.shape[2])),
    keras.layers.Flatten(),
    keras.layers.Dense(units=8)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 264
# =================================================================
# Total params: 264
# Trainable params: 264
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=keras.optimizers.Adam(0.001),
    metrics=["mean_absolute_error"]
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=40,
    verbose=1,
    shuffle=False
)
# Out:
# Epoch 1/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0056 - mean_absolute_error: 0.0549
# Epoch 2/40
# 36/36 [==============================] - 0s 666us/step - loss: 0.0038 - mean_absolute_error: 0.0441
# Epoch 3/40
# 36/36 [==============================] - 0s 637us/step - loss: 0.0033 - mean_absolute_error: 0.0409
# Epoch 4/40
# 36/36 [==============================] - 0s 776us/step - loss: 0.0030 - mean_absolute_error: 0.0387
# Epoch 5/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0027 - mean_absolute_error: 0.0368
# Epoch 6/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0025 - mean_absolute_error: 0.0352
# Epoch 7/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0023 - mean_absolute_error: 0.0338
# Epoch 8/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0022 - mean_absolute_error: 0.0326
# Epoch 9/40
# 36/36 [==============================] - 0s 776us/step - loss: 0.0021 - mean_absolute_error: 0.0315
# Epoch 10/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0020 - mean_absolute_error: 0.0305
# Epoch 11/40
# 36/36 [==============================] - 0s 637us/step - loss: 0.0019 - mean_absolute_error: 0.0296
# Epoch 12/40
# 36/36 [==============================] - 0s 748us/step - loss: 0.0018 - mean_absolute_error: 0.0288
# Epoch 13/40
# 36/36 [==============================] - 0s 666us/step - loss: 0.0017 - mean_absolute_error: 0.0281
# Epoch 14/40
# 36/36 [==============================] - 0s 692us/step - loss: 0.0017 - mean_absolute_error: 0.0275
# Epoch 15/40
# 36/36 [==============================] - 0s 694us/step - loss: 0.0016 - mean_absolute_error: 0.0269
# Epoch 16/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0016 - mean_absolute_error: 0.0264
# Epoch 17/40
# 36/36 [==============================] - 0s 637us/step - loss: 0.0015 - mean_absolute_error: 0.0259
# Epoch 18/40
# 36/36 [==============================] - 0s 748us/step - loss: 0.0015 - mean_absolute_error: 0.0255
# Epoch 19/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0015 - mean_absolute_error: 0.0251
# Epoch 20/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0014 - mean_absolute_error: 0.0247
# Epoch 21/40
# 36/36 [==============================] - 0s 684us/step - loss: 0.0014 - mean_absolute_error: 0.0243
# Epoch 22/40
# 36/36 [==============================] - 0s 637us/step - loss: 0.0014 - mean_absolute_error: 0.0240
# Epoch 23/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0014 - mean_absolute_error: 0.0237
# Epoch 24/40
# 36/36 [==============================] - 0s 609us/step - loss: 0.0013 - mean_absolute_error: 0.0234
# Epoch 25/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0013 - mean_absolute_error: 0.0232
# Epoch 26/40
# 36/36 [==============================] - 0s 748us/step - loss: 0.0013 - mean_absolute_error: 0.0229
# Epoch 27/40
# 36/36 [==============================] - 0s 720us/step - loss: 0.0013 - mean_absolute_error: 0.0227
# Epoch 28/40
# 36/36 [==============================] - 0s 687us/step - loss: 0.0013 - mean_absolute_error: 0.0225
# Epoch 29/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0013 - mean_absolute_error: 0.0223
# Epoch 30/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0012 - mean_absolute_error: 0.0221
# Epoch 31/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0012 - mean_absolute_error: 0.0219
# Epoch 32/40
# 36/36 [==============================] - 0s 629us/step - loss: 0.0012 - mean_absolute_error: 0.0217
# Epoch 33/40
# 36/36 [==============================] - 0s 666us/step - loss: 0.0012 - mean_absolute_error: 0.0216
# Epoch 34/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0012 - mean_absolute_error: 0.0214
# Epoch 35/40
# 36/36 [==============================] - 0s 609us/step - loss: 0.0012 - mean_absolute_error: 0.0213
# Epoch 36/40
# 36/36 [==============================] - 0s 693us/step - loss: 0.0012 - mean_absolute_error: 0.0212
# Epoch 37/40
# 36/36 [==============================] - 0s 665us/step - loss: 0.0012 - mean_absolute_error: 0.0211
# Epoch 38/40
# 36/36 [==============================] - 0s 610us/step - loss: 0.0012 - mean_absolute_error: 0.0210
# Epoch 39/40
# 36/36 [==============================] - 0s 637us/step - loss: 0.0012 - mean_absolute_error: 0.0208
# Epoch 40/40
# 36/36 [==============================] - 0s 651us/step - loss: 0.0011 - mean_absolute_error: 0.0207

# %%
history

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.00034036,  0.10804792, -0.00500164, ...,  0.001093  ,
#          0.00842565, -0.00047662],
#        [ 0.00384266,  0.11741167, -0.00547546, ...,  0.01580982,
#         -0.00854052, -0.00242794],
#        [ 0.01318048,  0.10275171, -0.00279939, ...,  0.00430777,
#          0.00165154, -0.0048319 ],
#        ...,
#        [ 0.00223923,  0.10236298, -0.00590169, ...,  0.0083628 ,
#          0.00319435,  0.00389742],
#        [-0.00257953,  0.11329158, -0.00825884, ...,  0.00706812,
#         -0.02277118, -0.00642128],
#        [ 0.00449419,  0.09511436, -0.00951952, ..., -0.00612581,
#         -0.02732923, -0.03515932]], dtype=float32)

# %%
y_test
# Out:
# array([[ 0.00982,  0.10054, -0.0047 , ...,  0.     , -0.016  ,  0.008  ],
#        [ 0.00966,  0.11234, -0.0033 , ...,  0.01   ,  0.015  ,  0.005  ],
#        [ 0.00965,  0.10664, -0.0032 , ...,  0.011  ,  0.01   ,  0.008  ],
#        ...,
#        [ 0.00986,  0.07976,  0.0033 , ...,  0.     , -0.049  , -0.002  ],
#        [ 0.00986,  0.08956,  0.0009 , ..., -0.01   , -0.002  , -0.001  ],
#        [ 0.00986,  0.07501,  0.0007 , ..., -0.007  , -0.025  , -0.002  ]])

# %%
model.evaluate(X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 554us/step - loss: 2.8960e-04 - mean_absolute_error: 0.0125
# [0.0002896023797802627, 0.012474733404815197]

# %%
model.metrics_names
# Out:
# ['loss', 'mean_absolute_error']

# %%
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['mean_absolute_error'])

# %%
y_err = np.abs(y_pred - y_test)

# %%
fig, ax = plt.subplots()
ax.plot(y_err)
# Out:
# [<matplotlib.lines.Line2D at 0x24c0e092348>,
#  <matplotlib.lines.Line2D at 0x24c0e0b23c8>,
#  <matplotlib.lines.Line2D at 0x24c0e0bc7c8>,
#  <matplotlib.lines.Line2D at 0x24c0e0c4908>,
#  <matplotlib.lines.Line2D at 0x24c0e0c4b88>,
#  <matplotlib.lines.Line2D at 0x24c0e0c4d48>,
#  <matplotlib.lines.Line2D at 0x24c0e0c4e88>,
#  <matplotlib.lines.Line2D at 0x24c0e0d0048>]

# %% [markdown]
# ## Save Model

# %%
#model.save("all_channel_linear.h5")

# %%
#!tensorflowjs_converter --input_format keras "all_channel_linear.h5" ./all_channel_linear_js
# Out:
# 2020-11-17 12:04:01.399633: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-11-17 12:04:01.399881: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# model:
# timesteps: 4
# feature 1: export => /100000 => NNmodel=> predicted value/100000
# feature 2: import => /100000 => NNmodel => predicted value/100000
# feature 3: WTI => difference => /100 => NNmodel => predicted difference/100
# feature 4: eastCoast => difference => NNmodel => predicted difference => +last price => predicted price
# feature 5: midwest => difference => NNmodel => predicted difference => +last price => predicted price
# feature 6: gulfCoast => difference => NNmodel => predicted difference => +last price => predicted price
# feature 7: rockyMountain => difference => NNmodel => predicted difference => +last price => predicted price
# feature 8: westCoast => difference => NNmodel => predicted difference => +last price => predicted price
